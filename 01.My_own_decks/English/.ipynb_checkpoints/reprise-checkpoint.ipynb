# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from requests.exceptions import HTTPError
from random import randint
import time

# %%
df = pd.read_csv("./scraped_words.csv")
df.head(25)
# Out:
#          words levels                                           def_urls  \
# 0            a     A1  https://www.oxfordlearnersdictionaries.com/def...
# 1      abandon     B2  https://www.oxfordlearnersdictionaries.com/def...
# 2      ability     A2  https://www.oxfordlearnersdictionaries.com/def...
# 3         able     A2  https://www.oxfordlearnersdictionaries.com/def...
# 4      abolish     C1  https://www.oxfordlearnersdictionaries.com/def...
# 5     abortion     C1  https://www.oxfordlearnersdictionaries.com/def...
# 6        about     A1  https://www.oxfordlearnersdictionaries.com/def...
# 7        about     A1  https://www.oxfordlearnersdictionaries.com/def...
# 8        above     A1  https://www.oxfordlearnersdictionaries.com/def...
# 9        above     A1  https://www.oxfordlearnersdictionaries.com/def...
# 10      abroad     A2  https://www.oxfordlearnersdictionaries.com/def...
# 11     absence     C1  https://www.oxfordlearnersdictionaries.com/def...
# ...

# %%
df[df["definition_1"].isnull()]["def_urls"].values
# Out:
# array(['https://www.oxfordlearnersdictionaries.com/definition/english/abortion',
#        'https://www.oxfordlearnersdictionaries.com/definition/english/absent_1',
#        'https://www.oxfordlearnersdictionaries.com/definition/english/abuse_2',
#        ...,
#        'https://www.oxfordlearnersdictionaries.com/definition/english/youth',
#        'https://www.oxfordlearnersdictionaries.com/definition/english/zero_1',
#        'https://www.oxfordlearnersdictionaries.com/definition/english/zone_1'],
#       dtype=object)

# %%
df = pd.read_csv("./scraped_words.csv")
df.head(40)
# Out:
#              words levels                                           def_urls  \
# 0                a     A1  https://www.oxfordlearnersdictionaries.com/def...
# 1          abandon     B2  https://www.oxfordlearnersdictionaries.com/def...
# 2          ability     A2  https://www.oxfordlearnersdictionaries.com/def...
# 3             able     A2  https://www.oxfordlearnersdictionaries.com/def...
# 4          abolish     C1  https://www.oxfordlearnersdictionaries.com/def...
# 5         abortion     C1  https://www.oxfordlearnersdictionaries.com/def...
# 6            about     A1  https://www.oxfordlearnersdictionaries.com/def...
# 7            about     A1  https://www.oxfordlearnersdictionaries.com/def...
# 8            above     A1  https://www.oxfordlearnersdictionaries.com/def...
# 9            above     A1  https://www.oxfordlearnersdictionaries.com/def...
# 10          abroad     A2  https://www.oxfordlearnersdictionaries.com/def...
# ...

# %%
df.shape
# Out:
# (5948, 29)
